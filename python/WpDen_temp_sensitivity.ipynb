# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Section = 1

# --------------------------------------------------------
# Section = 1
# Use this section if you want to test the wet radius's 
# sensitivity to temperautre
# --------------------------------------------------------
if Section==1:
    # Input:
    Den_h2so4 = 1.8 # g/cm³

    tmp = [180,240,280] # temperature [K]
    tmp = np.array(tmp)

    aw = [0.0123, 0.5, 0.7, 0.9, 0.99] # = relative humidity / 100

    # [um]
    Rdry = [0.00039422487,0.0004961,0.0006251,0.0007875,0.0009922,0.0012501,0.0015750,0.0019844,\
        0.0025002,0.0031501,0.0039689,0.0050004,0.0063002,0.0079377,0.0100009,0.0126003,\
        0.0158754,0.0200018,0.0252006,0.0317508,0.0400035,0.0504013,0.0635016,0.0800070,\
        0.1008026,0.1270033,0.1600141,0.2016051,0.2540065,0.3200282,0.4032103,0.5080131,\
        0.6400564,0.8064206,1.0160263,1.2801129,1.6128411,2.0320525,2.5602257,3.2256823]
    Rdry = np.array(Rdry)
    
# ------------------------------------------------------------------------
# Section = 2
# Use this section if you want to calculate the wet radius for 40 bins
# ------------------------------------------------------------------------
if Section==2:
    # Input:
    Den_h2so4 = 1.8 # g/cm³

    tmp = [240] # temperature [K]
    tmp = np.array(tmp)

    aw = [0.0, 0.5, 0.7, 0.8, 0.9, 0.95, 0.99] # = relative humidity / 100

    # [um]
    Rdry = [0.00039422487,0.0004961,0.0006251,0.0007875,0.0009922,0.0012501,0.0015750,0.0019844,\
        0.0025002,0.0031501,0.0039689,0.0050004,0.0063002,0.0079377,0.0100009,0.0126003,\
        0.0158754,0.0200018,0.0252006,0.0317508,0.0400035,0.0504013,0.0635016,0.0800070,\
        0.1008026,0.1270033,0.1600141,0.2016051,0.2540065,0.3200282,0.4032103,0.5080131,\
        0.6400564,0.8064206,1.0160263,1.2801129,1.6128411,2.0320525,2.5602257,3.2256823]
    Rdry = np.array(Rdry)

# %%
# !        calculation of particle density
# !        requires Temperature (temp) and acid mass fraction (so4mfrac)
# !
# !
# !---->Vehkamaeki et al., 2002  (JGR, doi:10.1029/2002JD002184)

def density(temp,so4mfrac):
    
    a1= 0.7681724
    a2= 2.184714
    a3= 7.163002
    a4=-44.31447
    a5= 88.74606
    a6=-75.73729
    a7= 23.43228
    
    b1= 1.808225e-3
    b2=-9.294656e-3
    b3=-3.742148e-2
    b4= 2.565321e-1
    b5=-5.362872e-1
    b6= 4.857736e-1
    b7=-1.629592e-1
     
    c1=-3.478524e-6
    c2= 1.335867e-5
    c3= 5.195706e-5
    c4=-3.717636e-4
    c5= 7.990811e-4
    c6=-7.458060e-4
    c7= 2.581390e-4
    
 
    so4m2=so4mfrac*so4mfrac
    so4m3=so4mfrac*so4m2
    so4m4=so4mfrac*so4m3
    so4m5=so4mfrac*so4m4
    so4m6=so4mfrac*so4m5

    a=a1+a2*so4mfrac+a3*so4m2+a4*so4m3 +a5*so4m4+a6*so4m5+a7*so4m6
    b=b1+b2*so4mfrac+b3*so4m2+b4*so4m3 +b5*so4m4+b6*so4m5+b7*so4m6
    c=c1+c2*so4mfrac+c3*so4m2+c4*so4m3 +c5*so4m4+c6*so4m5+c7*so4m6
      
    density=(a+b*temp+c*temp*temp) # units are g/cm**3
        
    return density

# %%
print(f'Rdry={Rdry[:]}')

Rwet = np.zeros((len(tmp), len(aw), len(Rdry)))

for i in range(len(tmp)):
    for k in range(len(aw)):
        
        if abs(aw[k])<1e-10:
            print("The wet radius is same as the dry radius")
            print("Just stop and no need to run the rest!")
            Rwet[i,k,:] = Rdry[:]
            
        else:
            if aw[k]>1.0: aw[k]=1.0
            if aw[k]<=0.05:
                y1=12.372089320*aw[k]**(-0.16125516114) -30.490657554*aw[k] -2.1133114241
                y2=13.455394705*aw[k]**(-0.19213122550) -34.285174607*aw[k] -1.7620073078
            elif aw[k]<=0.85:
                y1=11.820654354*aw[k]**(-0.20786404244) -4.8073063730*aw[k] -5.1727540348
                y2=12.891938068*aw[k]**(-0.23233847708) -6.4261237757*aw[k] -4.9005471319
            else:
                y1=-180.06541028*aw[k]**(-0.38601102592) -93.317846778*aw[k] +273.88132245
                y2=-176.95814097*aw[k]**(-0.36257048154) -90.469744201*aw[k] +267.45509988

            sulfmolal=y1+((tmp[i]-190.)*(y2-y1)/70.)
        
            wp=9800.*sulfmolal/(98.*sulfmolal+1000.) # weight percentage
        
            if wp<15.0: wp=15.0
            if wp>99.0: wp=99.0
            if wp<15.0 or wp>100.0:
                print( 'weight percent= ',wp,  ', T=',tmp[i], ', RH(aw)=', aw[k])
                print('*** Stupid Value of Weight Percent ***')
             
                
            # mass fraction
            wpp=wp*0.01
            # mole fraction
            xa=18.*wpp/(18.*wpp+98.*(1.-wpp))
        
        
            den = density(tmp[i],wpp)
        
        
            Vdry = 4/3 *np.pi * Rdry[:]**3
            Mdry = Den_h2so4*Vdry[:]

            Mwet = Mdry[:]/wpp
            Vwet = Mwet[:]/den
        
            Rwet[i,k,:] = (Vwet[:] / (4/3 *np.pi))**(1/3)
        
            print( f'temp={tmp[i]:.1f}K, RH={aw[k]*100:.1f}%, wp={wp:.3f} %, xa={xa:.3f}, den={den:.3f} gm/cm**3' )
            print(f'Rwet={Rwet[i,k,:]}')
            print('')
# Out:
# Rdry=[3.9422487e-04 4.9610000e-04 6.2510000e-04 7.8750000e-04 9.9220000e-04
#  1.2501000e-03 1.5750000e-03 1.9844000e-03 2.5002000e-03 3.1501000e-03
#  3.9689000e-03 5.0004000e-03 6.3002000e-03 7.9377000e-03 1.0000900e-02
#  1.2600300e-02 1.5875400e-02 2.0001800e-02 2.5200600e-02 3.1750800e-02
#  4.0003500e-02 5.0401300e-02 6.3501600e-02 8.0007000e-02 1.0080260e-01
#  1.2700330e-01 1.6001410e-01 2.0160510e-01 2.5400650e-01 3.2002820e-01
#  4.0321030e-01 5.0801310e-01 6.4005640e-01 8.0642060e-01 1.0160263e+00
#  1.2801129e+00 1.6128411e+00 2.0320525e+00 2.5602257e+00 3.2256823e+00]
# temp=180.0K, RH=1.2%, wp=68.047 %, xa=0.281, den=1.700 gm/cm**3
# Rwet=[4.56802180e-04 5.74848465e-04 7.24325288e-04 9.12503863e-04
#  1.14969693e-03 1.44853470e-03 1.82500773e-03 2.29939386e-03
#  2.89706941e-03 3.65013132e-03 4.59890359e-03 5.79413881e-03
#  7.30026265e-03 9.19769131e-03 1.15883935e-02 1.46004094e-02
#  1.83953826e-02 2.31767870e-02 2.92008188e-02 3.67907653e-02
#  4.63534581e-02 5.84017536e-02 7.35815305e-02 9.27069162e-02
#  1.16803507e-01 1.47163177e-01 1.85413948e-01 2.33606898e-01
#  2.94326238e-01 3.70827897e-01 4.67213913e-01 5.88652592e-01
#  7.41655793e-01 9.34427825e-01 1.17730530e+00 1.48331170e+00
#  1.86885553e+00 2.35461048e+00 2.96662329e+00 3.73771118e+00]
#
# temp=180.0K, RH=50.0%, wp=36.793 %, xa=0.097, den=1.361 gm/cm**3
# Rwet=[6.03925067e-04 7.59990677e-04 9.57609700e-04 1.20639520e-03
#  1.51998135e-03 1.91506621e-03 2.41279040e-03 3.03996271e-03
#  3.83013242e-03 4.82573399e-03 6.08007861e-03 7.66026483e-03
#  9.65146798e-03 1.21600040e-02 1.53206829e-02 1.93027828e-02
#  2.43200081e-02 3.06413657e-02 3.86055655e-02 4.86400161e-02
#  6.12825782e-02 7.72112843e-02 9.72800322e-02 1.22565156e-01
#  1.54422569e-01 1.94560218e-01 2.45130466e-01 3.08844984e-01
#  3.89120282e-01 4.90260932e-01 6.17690121e-01 7.78240717e-01
#  9.80521864e-01 1.23538024e+00 1.55648159e+00 1.96104388e+00
#  2.47076033e+00 3.11296302e+00 3.92208761e+00 4.94152081e+00]
#
# temp=180.0K, RH=70.0%, wp=28.829 %, xa=0.069, den=1.286 gm/cm**3
# Rwet=[6.67493275e-04 8.39986107e-04 1.05840620e-03 1.33337847e-03
#  1.67997221e-03 2.11664308e-03 2.66675694e-03 3.35994443e-03
#  4.23328616e-03 5.33368320e-03 6.72005818e-03 8.46657233e-03
#  1.06673664e-02 1.34399470e-02 1.69333140e-02 2.13345635e-02
#  2.68798941e-02 3.38666279e-02 4.26691270e-02 5.37597881e-02
#  6.77330866e-02 8.53384233e-02 1.07519576e-01 1.35466173e-01
#  1.70676847e-01 2.15039322e-01 2.70932516e-01 3.41353524e-01
#  4.30078474e-01 5.41865031e-01 6.82707217e-01 8.60157118e-01
#  1.08373006e+00 1.36541443e+00 1.72031441e+00 2.16746029e+00
#  2.73082870e+00 3.44062864e+00 4.33492042e+00 5.46165757e+00]
#
# temp=180.0K, RH=90.0%, wp=18.914 %, xa=0.041, den=1.186 gm/cm**3
# Rwet=[7.89148984e-04 9.93079941e-04 1.25130875e-03 1.57639680e-03
#  1.98615988e-03 2.50241732e-03 3.15279361e-03 3.97231976e-03
#  5.00483465e-03 6.30578739e-03 7.94483971e-03 1.00096693e-02
#  1.26115748e-02 1.58894792e-02 2.00195388e-02 2.52229494e-02
#  3.17789585e-02 4.00390775e-02 5.04458987e-02 6.35579169e-02
#  8.00779549e-02 1.00891998e-01 1.27115834e-01 1.60155910e-01
#  2.01783995e-01 2.54231868e-01 3.20312020e-01 4.03567790e-01
#  5.08463536e-01 6.40624040e-01 8.07135781e-01 1.01692727e+00
#  1.28124808e+00 1.61427156e+00 2.03385474e+00 2.56249636e+00
#  3.22854292e+00 4.06770929e+00 5.12499252e+00 6.45708605e+00]
#
# temp=180.0K, RH=99.0%, wp=15.000 %, xa=0.031, den=1.144 gm/cm**3
# Rwet=[8.62973334e-04 1.08598189e-03 1.36836783e-03 1.72386765e-03
#  2.17196379e-03 2.73651676e-03 3.44773530e-03 4.34392758e-03
#  5.47303352e-03 6.89568951e-03 8.68807405e-03 1.09460670e-02
#  1.37913790e-02 1.73759292e-02 2.18923530e-02 2.75825391e-02
#  3.47518584e-02 4.37847060e-02 5.51650782e-02 6.95037168e-02
#  8.75691931e-02 1.10330375e-01 1.39007434e-01 1.75138386e-01
#  2.20660751e-01 2.78015086e-01 3.50276991e-01 4.41321283e-01
#  5.56029953e-01 7.00553982e-01 8.82642784e-01 1.11206013e+00
#  1.40110796e+00 1.76528557e+00 2.22412047e+00 2.80221615e+00
#  3.53057092e+00 4.44824072e+00 5.60443208e+00 7.06114205e+00]
#
# temp=240.0K, RH=1.2%, wp=72.784 %, xa=0.329, den=1.697 gm/cm**3
# Rwet=[4.46954521e-04 5.62455986e-04 7.08710415e-04 8.92832269e-04
#  1.12491197e-03 1.41730745e-03 1.78566454e-03 2.24982394e-03
#  2.83461491e-03 3.57144245e-03 4.49976126e-03 5.66922982e-03
#  7.14288491e-03 8.99940915e-03 1.13385730e-02 1.42856564e-02
#  1.79988183e-02 2.26771460e-02 2.85713129e-02 3.59976366e-02
#  4.53541787e-02 5.71427391e-02 7.19952732e-02 9.07083573e-02
#  1.14285478e-01 1.43990660e-01 1.81416828e-01 2.28570843e-01
#  2.87981206e-01 3.62833656e-01 4.57141800e-01 5.75962526e-01
#  7.25667312e-01 9.14283599e-01 1.15192516e+00 1.45133474e+00
#  1.82856709e+00 2.30385022e+00 2.90266936e+00 3.65713428e+00]
#
# temp=240.0K, RH=50.0%, wp=39.843 %, xa=0.108, den=1.342 gm/cm**3
# Rwet=[5.90875313e-04 7.43568620e-04 9.36917445e-04 1.18032713e-03
#  1.48713724e-03 1.87368501e-03 2.36065426e-03 2.97427448e-03
#  3.74737001e-03 4.72145840e-03 5.94869884e-03 7.49474003e-03
#  9.44291679e-03 1.18972478e-02 1.49896299e-02 1.88856837e-02
#  2.37944956e-02 2.99792599e-02 3.77713674e-02 4.75889912e-02
#  5.99583699e-02 7.55428847e-02 9.51779824e-02 1.19916740e-01
#  1.51085769e-01 1.90356115e-01 2.39833629e-01 3.02171389e-01
#  3.80712080e-01 4.79667259e-01 6.04342928e-01 7.61424309e-01
#  9.59334517e-01 1.20868586e+00 1.52284877e+00 1.91866918e+00
#  2.41737156e+00 3.04569739e+00 3.83733822e+00 4.83474327e+00]
#
# temp=240.0K, RH=70.0%, wp=30.550 %, xa=0.075, den=1.260 gm/cm**3
# Rwet=[6.59178235e-04 8.29522304e-04 1.04522151e-03 1.31676842e-03
#  1.65904461e-03 2.09027582e-03 2.63353685e-03 3.31808922e-03
#  4.18055163e-03 5.26724090e-03 6.63634564e-03 8.36110327e-03
#  1.05344818e-02 1.32725241e-02 1.67223737e-02 2.10687964e-02
#  2.65450482e-02 3.34447475e-02 4.21375928e-02 5.30900963e-02
#  6.68893277e-02 8.42753528e-02 1.06180193e-01 1.33778655e-01
#  1.68550706e-01 2.12360552e-01 2.67557478e-01 3.37101244e-01
#  4.24720938e-01 5.35114956e-01 6.74202655e-01 8.49442042e-01
#  1.07022991e+00 1.34840531e+00 1.69888425e+00 2.14045999e+00
#  2.69681045e+00 3.39776834e+00 4.28091982e+00 5.39362107e+00]
#
# temp=240.0K, RH=90.0%, wp=17.952 %, xa=0.039, den=1.151 gm/cm**3
# Rwet=[8.11079997e-04 1.02067834e-03 1.28608351e-03 1.62020599e-03
#  2.04135668e-03 2.57196129e-03 3.24041199e-03 4.08271337e-03
#  5.14392257e-03 6.48102972e-03 8.16563247e-03 1.02878451e-02
#  1.29620594e-02 1.63310592e-02 2.05758960e-02 2.59239131e-02
#  3.26621184e-02 4.11517921e-02 5.18478263e-02 6.53242368e-02
#  8.23033784e-02 1.03695858e-01 1.30648474e-01 1.64606757e-01
#  2.07391717e-01 2.61297153e-01 3.29213719e-01 4.14783227e-01
#  5.22594100e-01 6.58427439e-01 8.29566660e-01 1.04518841e+00
#  1.31685488e+00 1.65913332e+00 2.09037702e+00 2.63370996e+00
#  3.31826644e+00 4.18075383e+00 5.26741972e+00 6.63653308e+00]
#
# temp=240.0K, RH=99.0%, wp=15.000 %, xa=0.031, den=1.126 gm/cm**3
# Rwet=[8.67649810e-04 1.09186686e-03 1.37578306e-03 1.73320934e-03
#  2.18373372e-03 2.75134602e-03 3.46641867e-03 4.36746744e-03
#  5.50269204e-03 6.93305743e-03 8.73515496e-03 1.10053841e-02
#  1.38661149e-02 1.74700898e-02 2.20109882e-02 2.77320096e-02
#  3.49401797e-02 4.40219765e-02 5.54640193e-02 6.98803593e-02
#  8.80437329e-02 1.10928259e-01 1.39760719e-01 1.76087466e-01
#  2.21856517e-01 2.79521657e-01 3.52175152e-01 4.43712815e-01
#  5.59043095e-01 7.04350303e-01 8.87425849e-01 1.11808641e+00
#  1.40870061e+00 1.77485170e+00 2.23617304e+00 2.81740143e+00
#  3.54970318e+00 4.47234586e+00 5.63480265e+00 7.09940657e+00]
#
# temp=280.0K, RH=1.2%, wp=75.231 %, xa=0.358, den=1.686 gm/cm**3
# Rwet=[4.43038656e-04 5.57528188e-04 7.02501250e-04 8.85009974e-04
#  1.11505638e-03 1.40489012e-03 1.77001995e-03 2.23011275e-03
#  2.80978024e-03 3.54015228e-03 4.46033788e-03 5.61956047e-03
#  7.08030455e-03 8.92056339e-03 1.12392333e-02 1.41604967e-02
#  1.78411268e-02 2.24784667e-02 2.83209934e-02 3.56822535e-02
#  4.49568209e-02 5.66420993e-02 7.13645071e-02 8.99136418e-02
#  1.13284199e-01 1.42729127e-01 1.79827396e-01 2.26568285e-01
#  2.85458141e-01 3.59654792e-01 4.53136682e-01 5.70916394e-01
#  7.19309584e-01 9.06273364e-01 1.14183290e+00 1.43861928e+00
#  1.81254661e+00 2.28366569e+00 2.87723845e+00 3.62509334e+00]
#
# temp=280.0K, RH=50.0%, wp=41.717 %, xa=0.116, den=1.328 gm/cm**3
# Rwet=[5.83918804e-04 7.34814419e-04 9.25886905e-04 1.16643087e-03
#  1.46962884e-03 1.85162569e-03 2.33286174e-03 2.93925768e-03
#  3.70325138e-03 4.66587160e-03 5.87866347e-03 7.40650276e-03
#  9.33174320e-03 1.17571788e-02 1.48131536e-02 1.86633383e-02
#  2.35143576e-02 2.96263073e-02 3.73266766e-02 4.70287153e-02
#  5.92524665e-02 7.46535013e-02 9.40574306e-02 1.18504933e-01
#  1.49307003e-01 1.88115009e-01 2.37010014e-01 2.98613857e-01
#  3.76229870e-01 4.74020028e-01 5.97227862e-01 7.52459889e-01
#  9.48040056e-01 1.19445572e+00 1.50491993e+00 1.89608026e+00
#  2.38891130e+00 3.00983970e+00 3.79216037e+00 4.77782275e+00]
#
# temp=280.0K, RH=70.0%, wp=31.651 %, xa=0.078, den=1.241 gm/cm**3
# Rwet=[6.54734857e-04 8.23930673e-04 1.03817590e-03 1.30789237e-03
#  1.64786135e-03 2.07618572e-03 2.61578474e-03 3.29572269e-03
#  4.15237144e-03 5.23173557e-03 6.59161147e-03 8.30474287e-03
#  1.04634711e-02 1.31830569e-02 1.66096518e-02 2.09267762e-02
#  2.63661137e-02 3.32193037e-02 4.18535524e-02 5.27322274e-02
#  6.64384412e-02 8.37072708e-02 1.05464455e-01 1.32876882e-01
#  1.67414542e-01 2.10929076e-01 2.65753931e-01 3.34828917e-01
#  4.21857986e-01 5.31507862e-01 6.69658000e-01 8.43716137e-01
#  1.06301572e+00 1.33931600e+00 1.68743244e+00 2.12603161e+00
#  2.67863184e+00 3.37486471e+00 4.25206306e+00 5.35726384e+00]
#
# temp=280.0K, RH=90.0%, wp=17.298 %, xa=0.037, den=1.126 gm/cm**3
# Rwet=[8.27224630e-04 1.04099505e-03 1.31168314e-03 1.65245637e-03
#  2.08199010e-03 2.62315645e-03 3.30491273e-03 4.16398021e-03
#  5.24631290e-03 6.61003530e-03 8.32817025e-03 1.04926258e-02
#  1.32200706e-02 1.66561307e-02 2.09854614e-02 2.64399314e-02
#  3.33122613e-02 4.19709229e-02 5.28798628e-02 6.66245227e-02
#  8.39416359e-02 1.05759935e-01 1.33249045e-01 1.67883272e-01
#  2.11519871e-01 2.66498301e-01 3.35766753e-01 4.23039532e-01
#  5.32996391e-01 6.71533507e-01 8.46079273e-01 1.06599299e+00
#  1.34306701e+00 1.69215855e+00 2.13198619e+00 2.68613424e+00
#  3.38431688e+00 4.26397218e+00 5.37226826e+00 6.76863397e+00]
#
# temp=280.0K, RH=99.0%, wp=15.000 %, xa=0.031, den=1.108 gm/cm**3
# Rwet=[8.72089586e-04 1.09745396e-03 1.38282296e-03 1.74207819e-03
#  2.19490791e-03 2.76542470e-03 3.48415638e-03 4.38981583e-03
#  5.53084939e-03 6.96853398e-03 8.77985287e-03 1.10616988e-02
#  1.39370680e-02 1.75594845e-02 2.21236188e-02 2.78739147e-02
#  3.51189690e-02 4.42472376e-02 5.57478294e-02 7.02379381e-02
#  8.84942539e-02 1.11495880e-01 1.40475876e-01 1.76988508e-01
#  2.22991760e-01 2.80951974e-01 3.53977237e-01 4.45983299e-01
#  5.61903726e-01 7.07954474e-01 8.91966820e-01 1.12380767e+00
#  1.41590895e+00 1.78393364e+00 2.24761557e+00 2.83181812e+00
#  3.56786706e+00 4.49523091e+00 5.66363601e+00 7.13573433e+00]

# %%
wp
# Out:
# 15.0

# %%
# Rwet's sensitivity to temp
# Rwet = np.zeros((len(tmp), len(aw), len(Rdry)))

if Section==1:
    Diff = np.zeros(( len(aw), len(Rdry) ))

    for j in range(len(aw)):
        for k in range(len(Rdry)):
            Diff[j,k] = (np.max(Rwet[:,j,k])-np.min(Rwet[:,j,k]))/np.min(Rwet[:,j,k])
        
    print(f"The maximum different is {np.max(Diff*100):.1f}%" )

# %% [markdown]
# ## Conclusion: the change of wet radius caused by temperature is less than 2%, which indicates we can neglect temp's influence on wet radius in the stratosphere.

# %%
# output wet radius
# Rwet = np.zeros((len(tmp), len(aw), len(Rdry)))

if Section==2:
    import pandas as pd
    
    N_WV = 41
    N_RH = len(aw)
    N_column = 1+40*2 # RH, Radius_dry, Radius_wet
    Output = np.zeros((N_WV*N_RH, N_column))

    for i_RH in range(N_RH):
        for i_WV in range(N_WV):
            Output[i_RH*N_WV+i_WV, 0] = aw[i_RH]*100
            Output[i_RH*N_WV+i_WV, 1:41] = Rdry[0:40]
            Output[i_RH*N_WV+i_WV, 41::] = Rwet[0, i_RH, 0:40]


    df = pd.DataFrame(Output)
    df.to_csv('test.csv')

# %%
df
# Out:
#        0         1         2         3         4         5        6   \
# 0     0.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 1     0.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 2     0.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 3     0.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 4     0.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# ..    ...       ...       ...       ...       ...       ...      ...
# 282  99.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 283  99.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 284  99.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 285  99.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
# 286  99.0  0.000394  0.000496  0.000625  0.000788  0.000992  0.00125
#
#            7         8       9   ...        71        72        73        74  \
# 0    0.001575  0.001984  0.0025  ...  0.403210  0.508013  0.640056  0.806421
# 1    0.001575  0.001984  0.0025  ...  0.403210  0.508013  0.640056  0.806421
# 2    0.001575  0.001984  0.0025  ...  0.403210  0.508013  0.640056  0.806421
# 3    0.001575  0.001984  0.0025  ...  0.403210  0.508013  0.640056  0.806421
# 4    0.001575  0.001984  0.0025  ...  0.403210  0.508013  0.640056  0.806421
# ..        ...       ...     ...  ...       ...       ...       ...       ...
# 282  0.001575  0.001984  0.0025  ...  0.887426  1.118086  1.408701  1.774852
# 283  0.001575  0.001984  0.0025  ...  0.887426  1.118086  1.408701  1.774852
# 284  0.001575  0.001984  0.0025  ...  0.887426  1.118086  1.408701  1.774852
# 285  0.001575  0.001984  0.0025  ...  0.887426  1.118086  1.408701  1.774852
# 286  0.001575  0.001984  0.0025  ...  0.887426  1.118086  1.408701  1.774852
#
#            75        76        77        78        79        80
# 0    1.016026  1.280113  1.612841  2.032052  2.560226  3.225682
# 1    1.016026  1.280113  1.612841  2.032052  2.560226  3.225682
# 2    1.016026  1.280113  1.612841  2.032052  2.560226  3.225682
# 3    1.016026  1.280113  1.612841  2.032052  2.560226  3.225682
# 4    1.016026  1.280113  1.612841  2.032052  2.560226  3.225682
# ..        ...       ...       ...       ...       ...       ...
# 282  2.236173  2.817401  3.549703  4.472346  5.634803  7.099407
# 283  2.236173  2.817401  3.549703  4.472346  5.634803  7.099407
# 284  2.236173  2.817401  3.549703  4.472346  5.634803  7.099407
# 285  2.236173  2.817401  3.549703  4.472346  5.634803  7.099407
# 286  2.236173  2.817401  3.549703  4.472346  5.634803  7.099407
#
# [287 rows x 81 columns]
